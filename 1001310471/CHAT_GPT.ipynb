# %% [markdown]
# # Practice with Chat GPT
#
# # We create a few questions to learn about the leanguage of the IA

# %% [markdown]
# ![Captura de pantalla 2023-02-13 222054.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
